# %%
from fussballgott import load, league, plot, team
# Out:
# WELCOME TO THE FUSSBALLGOTT PACKAGE
#
#                        _,aaadP""""""Ybaaaa,,_
#                    ,adP,__,,,aaaadP"""""Y888888a,_
#                 ,a8888888P"''             "Y8888888b,
#              _a888888888"                   `Y88888888b,
#            ,d888888888P'                       "888888888b,
#          ,88888888P"Y8,                       ,P'   `""Y888b,
#        ,d8888P"'     "Ya,                    ,P'         `Ya`b,
#       ,P88"'           `Ya,                 ,P'            `b`Yi
#      d",P                `"Y,              ,P'              `Y "i
#    ,P' P'                   "888888888888888b                `b "i
#   ,P' d'                    d8888888888888888b                `b `b
#   d' d'                    ,888888888888888888b                I, Y,
#  ,f ,f                    ,88888888888888888888b               `b, b
#  d' d'                    d888888888888888888888b              ,88,I
# ,P  8                    ,88888888888888888888888b,_          ,d8888
# d'  8,                   d8888888888888888888888P'`"Ya,_     ,d88888
# 8  d88b,             ,adP""Y888888888888888888P'      `""Ya, d88888P
# 8 ,88888b,       ,adP"'     `"Y8888888888888"'             `"888888I
# Y,88888888b, ,adP"'             ""Y888888P"                  888888'
# `888888888888P'                     ""YP"                    888888
#  I88888888888                          8                     88888I
#  `Y8888888888                          8                     88888'
#   `Y888888888                          8                     8888I
#    `Y88888888                          8                     8P"8'
#     `Y8888888,                         8                   ,d',d'
#      `b""""Y8b                         8                 ,d" ,d'
#        "b,   "Y,                       8               ,P" ,d"
#          "b,   "Ya,_                 ,d88ba,,___   _,aP" ,P"
#            "Ya_   ""Ya,_       _,,ad88888888888888P"' _,d"
#              `"Ya_    ""Yaaad88888888888888888888P _,d"'
#                  `"Ya,_     "Y888888888888888888P",d"'
#                     `""Ya,__`Y888888888888888P"""
#                          ``"""""""""""""''

# %% [markdown]
# # Full League simulation

# %%
teams = {}
teams["GCZ"] = team.team(name="GCZ", GoalsF=3.1, GoalsA=0.9)
teams["YB"] = team.team(name="FCB", GoalsF=2.3, GoalsA=1.7)
teams["FCB"] = team.team(name="FCB", GoalsF=2, GoalsA=3.2)
teams["FCZ"] = team.team(name="FCZ", GoalsF=1, GoalsA=4.3)

# %%
sim = league.simulate(teams, schedule=4, n_sim=1e5)
# Out:
# /Users/silvanfischbacher/Desktop/Silvan/fussballgott/fussballgott/league.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sch = sch.append(one_round, ignore_index=True)
# 100%|█████████████████████████████████████████████████████████████████████████████| 100000/100000 [00:10<00:00, 9908.11it/s]

# %%
plot.league(sim)

# %% [markdown]
# # League from schedule

# %%
file = "demo_league.CSV"
teams, schedule, table, missing_games = load.league(file)
# Out:
# /Users/silvanfischbacher/Desktop/Silvan/fussballgott/fussballgott/load.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   table["Played"][game["Home"].values[0]] += 1
# /Users/silvanfischbacher/Desktop/Silvan/fussballgott/fussballgott/load.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   table["Played"][game["Away"].values[0]] += 1
# /Users/silvanfischbacher/Desktop/Silvan/fussballgott/fussballgott/load.py:145: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   table["GF"][game["Home"].values[0]] += game["Goals Home"].values[0]
# /Users/silvanfischbacher/Desktop/Silvan/fussballgott/fussballgott/load.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   table["GF"][game["Away"].values[0]] += game["Goals Away"].values[0]
# /Users/silvanfischbacher/Desktop/Silvan/fussballgott/fussballgott/load.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   table["GA"][game["Home"].values[0]] += game["Goals Away"].values[0]
# /Users/silvanfischbacher/Desktop/Silvan/fussballgott/fussballgott/load.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   table["GA"][game["Away"].values[0]] += game["Goals Home"].values[0]
# /Users/silvanfischbacher/Desktop/Silvan/fussballgott/fussballgott/load.py:150: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   table["Points"][game["Home"].values[0]] += 3
# /Users/silvanfischbacher/Desktop/Silvan/fussballgott/fussballgott/load.py:152: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   table["Points"][game["Away"].values[0]] += 3
# /Users/silvanfischbacher/Desktop/Silvan/fussballgott/fussballgott/load.py:154: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   table["Points"][game["Home"].values[0]] += 1
# /Users/silvanfischbacher/Desktop/Silvan/fussballgott/fussballgott/load.py:155: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   table["Points"][game["Away"].values[0]] += 1

# %%
sim = league.simulate(teams, schedule, table, missing_games, n_sim=1e5)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 100000/100000 [00:03<00:00, 28469.34it/s]

# %%
plot.league(sim)

# %% [markdown]
# # League from schedule wo results and current table

# %%
file_sched = "demo_league_sep_schedule.CSV"
file_tab = "demo_league_sep_table.CSV"
teams, schedule, table, missing_games = load.league([file_sched, file_tab])

# %%
sim = league.simulate(teams, schedule, table, missing_games, n_sim=1e5)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 100000/100000 [00:03<00:00, 28722.83it/s]

# %%
plot.league(sim)
